# %% [markdown]
# # CAPSTONE PROJECT - The Battle of the Neighborhoods

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Modeling](#modeling)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## 1. Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# Istanbul is a very large city with a population of nearly 16 million. It has a population density of 2844 people per square kilometer. Its population increased over 1 million in last 5 years. The city divided into 39 Boroughs and 782 Neighborhoods. Being such a crowded city leads some health problems in aspects of citizens, especially nowadays when COVID-19 seriously threaten humanity. With a high population, health service planning becomes one of the major responsibilities for government and local managements. Authorities should effectively determine areas with weak health services and medical establishments and orient the funds for developments of health services in those areas. This project aims to classify areas according to their health and medical capabilities and find optimal locations for enhancing health service points and medical establishments.

# %% [markdown]
# ## 2. Data <a name="data"></a>

# %% [markdown]
# Based on definition of problem, lots of factors that will influence the decision should be considered as a parameter. For example number of existing medical establishments, number of beds, capabilities of emergency service or ambulance, number of intensive care units, number and branches of medical service personnel, number and type of diagnosis devices are some of them. But much of this information is not public. So only open data will be used in this project.
# These are:
# *	number of existing medical establishments in the neighborhood (specific type of health care services)
# *	number of beds, if any
# *	capabilities of emergency service or ambulance
#
# Following data sources will be needed to extract/generate the required information:
# *	Centers of Boroughs will be generated by using Google Maps
# *	Coordinate of Istanbul center obtained using geopy geolocator
# *	Number of medical establishments and their type and location in every neighborhood will be obtained using Istanbul Municipality Open Data Platform
# *	The Data is in the form of CSV. It is provided by Istanbul Municipality IT Department at their Open Data Platform. This is the link for the data.
# https://data.ibb.gov.tr/dataset/bd3b9489-c7d5-4ff3-897c-8667f57c70bb/resource/f2154883-68e3-41dc-b2be-a6c2eb721c9e/download/salk-kurum-ve-kurulularna-ait-bilgiler.csv

# %% [markdown]
# Let us import dependencies for our project

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import folium 
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib as plt
from matplotlib import pyplot
import seaborn as sns
from scipy.spatial.distance import cdist
# %matplotlib inline

# %% [markdown]
# Data set will be acquired from Istanbul Municipality Open Data Platform in CSV format. It includes names and types of those establishments, Boroughs, Neighborhoods, communication info, their capabilities such as emergency service, ambulance, number of beds and geolocal information. First we will add "First Aid Station" counts per Borough as a column into our dataframe.Unnecessary columns will be dropped so we can focus our main purposes. Column names and records are in Turkish, they are causing some problems with utf-8 encoding so we will translate them to English and manipulate some of them. We will drop some records that include only side health services (for example dialysis centers, veterinaries, physical rehabilitation centers) We will convert 'Ambulance' and 'Emergency_Service' column records to numerical data so we can use them. 1 will refer to existence and 0 will refer to non-existence. We will also drop rows that 'Ambulance','Emergency_Service' and 'Bed' records includes NaN values. At last we will count Firs Aid Stations and add as a column.

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("https://data.ibb.gov.tr/dataset/bd3b9489-c7d5-4ff3-897c-8667f57c70bb/resource/f2154883-68e3-41dc-b2be-a6c2eb721c9e/download/salk-kurum-ve-kurulularna-ait-bilgiler.csv", encoding="iso-8859-1")

# %%
# Dropping unnecessary fields
df.drop(columns = ['ILCE_UAVT', 'ADRES', 'TELEFON','WEBSITESI'], inplace = True)

# %%
# Translation to English
df.rename(columns={'ILCE_ADI':'Borough', 'ADI':'Name', 'ALT_KATEGORI':'Type', 'ACIL_SERVIS':'Emergency_Service', 'YATAK':'Bed', 'AMBULANS':'Ambulance', 'MAHALLE': 'Neighborhood', 'ENLEM':'Latitude',
       'BOYLAM':'Longitude' }, inplace=True)

# %%
# Get names of indexes for dropping side health establishments such as dialysis centers, veterinaries, physical rehabilitation units
indexNames = df[(df['Type'] == 'Özel Aðýz Diþ Saðlýðý Merkezleri') | (df['Type'] == 'Veteriner') | (df['Type'] == 'Diyaliz Merkezi') | (df['Type'] == 'Aile Saðlýðý Merkezi') | (df['Type'].str.contains('Rehabilitasyon')) ].index
df.drop(indexNames , inplace=True)

# %%
# Translation to English
df['Type'].replace(to_replace=['Üniversite Hastanesi', 'Eðitim Araþtýrma Hastanesi', 'Týp Merkezi Özel', 'Devlet Hastanesi', 'Özel Hastane', 'Aile Saðlýðý Merkezi', 'Askeri Hastane', 'Kadýn Doðum ve Çocuk Hastanesi','Acil Yardým Ýstasyonu'], value=['University Hospital', 'Education and Research Hospital', 'Private Medical Center', 'State Hospital', 'Private Hospital', 'Family Health Center', 'Military Hospital', "Women and Children's Hospital", 'First Aid Station'],inplace=True)

# %%
# Manipulation of some records that have ASCII problem
df['Borough'].replace(to_replace=['FATÝH', 'ÞÝÞLÝ', 'SÝLÝVRÝ', 'BEÞÝKTAÞ', 'BAHÇELÝEVLER', 'BEYOÐLU', 'SULTANGAZÝ', 'ÜMRANÝYE', 'BAÐCILAR', 'PENDÝK', 'BAÞAKÞEHÝR', 'ATAÞEHÝR', 'ZEYTÝNBURNU', 'GAZÝOSMANPAÞA', 'BAYRAMPAÞA', 'ÞÝLE','BEYLÝKDÜZÜ', 'BÜYÜKÇEKMECE', 'EYÜPSULTAN', 'GÜNGÖREN', 'KADIKÖY', 'KÜÇÜKÇEKMECE', 'SULTANBEYLÝ', 'ÜSKÜDAR', 'ÇATALCA'], value=['FATIH', 'SISLI', 'SILIVRI', 'BESIKTAS', 'BAHCELIEVLER', 'BEYOGLU', 'SULTANGAZI', 'UMRANIYE', 'BAGCILAR', 'PENDIK', 'BASAKSEHIR', 'ATASEHIR', 'ZEYTINBURNU', 'GAZIOSMANPASA', 'BAYRAMPASA', 'SILE', 'BEYLIKDUZU', 'BUYUKCEKMECE', 'EYUPSULTAN', 'GUNGOREN', 'KADIKOY', 'KUCUKCEKMECE', 'SULTANBEYLI', 'USKUDAR', 'CATALCA'],inplace=True)

# %%
# Dropping rows with NaN values
df = df.dropna()

# %%
# Converting fields to numerical values
df['Emergency_Service'].replace(to_replace=['Var','Yok'], value=[1,0],inplace=True)
df['Ambulance'].replace(to_replace=['Var','Yok'], value=[1,0],inplace=True)

# %%
# Some records with 0 bed are dropped becouse of doubts about them.
df = df[df['Bed'] != 0.0]

# %%
df = df.sort_values('Borough')

# %%
df.reset_index(drop=True, inplace=True)

# %%
 # One of the biggest hospital bed count was wrong. It is updated
df.at[0, 'Bed'] = 1105.0

# %%
dummy_variable_1 = pd.get_dummies(df["Type"])
dummy_variable_1.drop(columns = ['Education and Research Hospital', 'Military Hospital', 'Private Hospital','Private Medical Center','State Hospital','University Hospital',"Women and Children's Hospital"], inplace = True)
df2= pd.merge(df, dummy_variable_1, left_index=True, right_index=True)
dfBoroughsByFAStations = df2.groupby('Borough', as_index=False)['First Aid Station'].sum()
dfBoroughsByFAStations.head()
# Out:
#       Borough  First Aid Station
# 0      ADALAR                  4
# 1  ARNAVUTKÖY                  2
# 2    ATASEHIR                  3
# 3     AVCILAR                  0
# 4    BAGCILAR                  6

# %% [markdown]
# We can get rid of records about First Aid Stations because we are not considering them as an establishment. But we wil add them later to calculation as a capability.

# %%
indexNames = df[(df['Type'] == 'First Aid Station')].index
df.drop(indexNames , inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#            Borough                                               Name  \
# 0           ADALAR  Kartal Dr. Lütfi Kýrdar Eðitim ve Araþtýrma Ha...
# 1       ARNAVUTKÖY                     Özel Avrupa Hospital Hastanesi
# 2       ARNAVUTKÖY                        Arnavutköy Devlet Hastanesi
# 3         ATASEHIR  SBÜ Fatih Sultan Mehmet Eðitim ve Araþtýrma Ha...
# 4         ATASEHIR       Özel Ataþehir Florance Nightingale Hastanesi
# 5         ATASEHIR                            Özel Eren Týp Hastanesi
# 6         ATASEHIR                 Özel Acýbadem Týp Merkezi Ataþehir
# 7         ATASEHIR                  Özel Bayýndýr Ýçerenköy Hastanesi
# 8         ATASEHIR                   Özel Memorial Hastanesi Ataþehir
# 9         ATASEHIR                  Özel Avicenna Hastanesi Ataþehir
# 10        ATASEHIR                    Yeditepe Üniversitesi Hastanesi
# 11         AVCILAR               Avcýlar Murat Kölük Devlet Hastanesi
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=264, step=1)

# %%
df.shape
# Out:
# (264, 9)

# %%
df.describe()
# Out:
#        Emergency_Service          Bed   Ambulance    Latitude   Longitude
# count         264.000000   264.000000  264.000000  264.000000  264.000000
# mean            0.950758   123.965909    0.700758   41.022165   28.951660
# std             0.216785   181.512558    0.458796    0.059590    0.182296
# min             0.000000     1.000000    0.000000   40.825990   28.153630
# 25%             1.000000    33.500000    0.000000   40.995203   28.859293
# 50%             1.000000    61.500000    1.000000   41.026296   28.939542
# 75%             1.000000   121.000000    1.000000   41.061310   29.059743
# max             1.000000  1391.000000    1.000000   41.181714   29.616857

# %% [markdown]
# This table gives us general informations about medical capabilities of Istanbul. There are 264 medical establishments in Istanbul. Average Emergency Service existence ratio, Bed count, and Ambulance existence ratio numbers, per medical facility, are respectively 0.95, 123,96, 0.70

# %% [markdown]
# ## 3. Methodology <a name="methodology"></a>

# %% [markdown]
# In this project we will direct our efforts on detecting areas, especially Boroughs that have precedence on funding for health service planning and Medical Service Establishments.
#
# In first step we have collected the required **data: location type (category) bed capacity, ambulace and emergency service existence ratio and first aid station counts of every boroughs in Istanbul center**.
#
# Second step in our analysis we will deep dive into data and try to resolve what kind of information can we use. We will explore **First Aid Counts Per Borougs, Types of Establisments and Their Counts across the city, Distribution of Establishments according to their types in each borough, Distribution of Beds according to Establishment Type** and try to present them by visualization charts. We will also use **boxplot** to identify relation between Establishment Type and Bed Counts and also detect outliers according to number of beds.
#
# In third and final step we will focus on boroughs with high precedency on funding for health service planning and Medical Service Establishments by **clustering boroughs with the help of k-means clustering algorithm.** We will present map of all such locations according to their classification.

# %% [markdown]
# ## 4. Analysis <a name="analysis"></a>

# %% [markdown]
# Let's perform some basic explanatory data analysis and derive some additional info from our raw data. First let's count the **number of medical establishments according to their types acccros Istanbul**:

# %%
dfFacilityCounts = df["Type"].value_counts().to_frame()
dfFacilityCounts['Facility Type']=dfFacilityCounts.index
dfFacilityCounts.reset_index(drop=True, inplace=True)
dfFacilityCounts.rename(columns={'Type': 'Facility_counts'}, inplace=True)
dfFacilityCounts = dfFacilityCounts[['Facility Type', 'Facility_counts']]
dfFacilityCounts
# Out:
#                      Facility Type  Facility_counts
# 0                 Private Hospital              151
# 1           Private Medical Center               38
# 2  Education and Research Hospital               32
# 3                   State Hospital               31
# 4              University Hospital                9
# 5    Women and Children's Hospital                2
# 6                Military Hospital                1

# %%
# set x/y labels and plot title
plt.pyplot.figure(figsize=(15.5,5.5))
pyplot.bar(dfFacilityCounts["Facility Type"], dfFacilityCounts["Facility_counts"], color=['red','orange','blue','cyan','navy','fuchsia','lime'])
plt.pyplot.xlabel("Types of Medical Establishments")
plt.pyplot.ylabel("count")
plt.pyplot.title("Number Of Medical Establishments According To Their Types")
# Out:
# Text(0.5, 1.0, 'Number Of Medical Establishments According To Their Types')

# %% [markdown]
# Let's see their distribution by means of borough.

# %%
dfBoroughTypes = df.groupby('Borough')['Type'].value_counts().to_frame()
dfBoroughTypes
# Out:
#                                                Type
# Borough       Type
# ADALAR        Education and Research Hospital     1
# ARNAVUTKÖY    Private Hospital                    1
#               State Hospital                      1
# ATASEHIR      Private Hospital                    4
#               Private Medical Center              2
#               Education and Research Hospital     1
#               University Hospital                 1
# AVCILAR       Private Hospital                    3
#               State Hospital                      1
# BAGCILAR      Private Medical Center             14
#               Private Hospital                    8
#               Education and Research Hospital     1
#               University Hospital                 1
# BAHCELIEVLER  Private Hospital                   11
#               Education and Research Hospital     2
#               State Hospital                      1
# BAKIRKÖY      Private Hospital                    5
# ...

# %%
dfTypesAndBeds = df[['Type','Bed']]

# %% [markdown]
# Let's look at the relationship between "Establishment Type" and "Bed counts". We can easily detect outliers with boxplot visualization.

# %%
pyplot.figure(figsize=(15,6))
sns.boxplot(x="Type", y="Bed", data=dfTypesAndBeds)

# %% [markdown]
# It is impotant to identify distribution of beds according to type of establishments and crete a pie chart for better undertanding the situation. It will be so meaningful info for discriminatig the private's and state's capability.

# %%
dfTypesBedTotal = df.groupby('Type', as_index=False)['Bed'].sum()
dfTypesBedTotal = dfTypesBedTotal.sort_values('Bed', ascending=False)
dfTypesBedTotal
# Out:
#                               Type      Bed
# 0  Education and Research Hospital  13763.0
# 2                 Private Hospital  12057.0
# 4                   State Hospital   3670.0
# 5              University Hospital   1403.0
# 3           Private Medical Center    317.0
# 1                Military Hospital    216.0
# 6    Women and Children's Hospital    201.0

# %%
colors_list = ['blue','red', 'cyan', 'navy','orange','lime','fuchsia']
explode_list = [0, 0, 0, 0, 0.2, 0.2,0.2] 
# autopct create %, start angle represent starting point
dfTypesBedTotal['Bed'].plot(kind='pie',
                            figsize=(15, 10),
                            autopct='%1.1f%%', # add in percentages
                            startangle=30,     # start angle
                            shadow=True,
                            labels=dfTypesBedTotal['Type'],# add shadow
                            colors=colors_list,  # add customized colors
                            explode=explode_list
                            )

plt.pyplot.title('Bed Counts Percentage According To Types of Establishments')
plt.pyplot.axis('equal') # Sets the pie chart to look like a circle.

plt.pyplot.show()

# %% [markdown]
# And also it will much meaningful seeing them by means of boroughs

# %%
dfBoroughAndTypesBeds = df.groupby(['Borough', 'Type'], as_index=False)['Bed'].sum()
dfBoroughAndTypesBeds
# Out:
#           Borough                             Type     Bed
# 0          ADALAR  Education and Research Hospital  1105.0
# 1      ARNAVUTKÖY                 Private Hospital    34.0
# 2      ARNAVUTKÖY                   State Hospital   201.0
# 3        ATASEHIR  Education and Research Hospital   300.0
# 4        ATASEHIR                 Private Hospital   425.0
# 5        ATASEHIR           Private Medical Center    53.0
# 6        ATASEHIR              University Hospital   152.0
# 7         AVCILAR                 Private Hospital   266.0
# 8         AVCILAR                   State Hospital   100.0
# 9        BAGCILAR  Education and Research Hospital   498.0
# 10       BAGCILAR                 Private Hospital   559.0
# 11       BAGCILAR           Private Medical Center    86.0
# 12       BAGCILAR              University Hospital   515.0
# 13   BAHCELIEVLER  Education and Research Hospital   288.0
# 14   BAHCELIEVLER                 Private Hospital   886.0
# ...

# %%
# Counts of Beds for each Borough
countsByTotalBedNumbers = df.groupby('Borough',as_index=False)['Bed'].sum()
countsByTotalBedNumbers = countsByTotalBedNumbers.sort_values('Bed', ascending=True)
countsByTotalBedNumbers.head()
# Out:
#          Borough    Bed
# 29          SILE   25.0
# 14       CATALCA   50.0
# 34         TUZLA  100.0
# 13  BUYUKCEKMECE  108.0
# 7     BASAKSEHIR  145.0

# %%
countsByTotalBedNumbers.plot.barh(x='Borough', y='Bed', figsize=(15,10))

# %% [markdown]
# This chart nicely covers density of beds by means of borough

# %% [markdown]
# Then We can list Boroughs by means of their average Emergency Service, Bed and Ambulance numbers. These are average numbers with respect to numbers of total medical establishment in that Borough

# %%
groupedByBr = df.groupby('Borough').mean().reset_index()
groupedByBr.head()
# Out:
#       Borough  Emergency_Service          Bed  Ambulance   Latitude  Longitude
# 0      ADALAR           1.000000  1105.000000   1.000000  40.870022  29.128099
# 1  ARNAVUTKÖY           1.000000   117.500000   0.500000  41.179635  28.745557
# 2    ATASEHIR           1.000000   116.250000   1.000000  40.977382  29.107801
# 3     AVCILAR           1.000000    91.500000   0.500000  40.991604  28.717076
# 4    BAGCILAR           0.916667    69.083333   0.458333  41.042299  28.844779

# %% [markdown]
# Now we are aproaching a meaningful table for clustering. We are trying to collect all kind of info about boroughs in form of numbers about health and medical service capability. We are mergin two frame and adding First Aid Station number. After we are trying to find aid capability radio by multiplying number of first aid stations and ambulance ratio.

# %%
merged_df = pd.merge(groupedByBr, countsByTotalBedNumbers, on='Borough')
merged_df.drop(columns = ['Bed_x'], inplace = True)
merged_df.rename(columns={'Bed_y':'Bed_Counts', 'Emergency_Service': 'Emergency_Service_Ratio', 'Ambulance':'Ambulance_Ratio'}, inplace = True)
merged_df = pd.merge(merged_df, dfBoroughsByFAStations, on='Borough')
merged_df = merged_df[['Borough', 'Emergency_Service_Ratio', 'Ambulance_Ratio', 'Bed_Counts', 'First Aid Station', 'Latitude', 'Longitude',]]
merged_df.head()
# Out:
#       Borough  Emergency_Service_Ratio  Ambulance_Ratio  Bed_Counts  \
# 0      ADALAR                 1.000000         1.000000      1105.0
# 1  ARNAVUTKÖY                 1.000000         0.500000       235.0
# 2    ATASEHIR                 1.000000         1.000000       930.0
# 3     AVCILAR                 1.000000         0.500000       366.0
# 4    BAGCILAR                 0.916667         0.458333      1658.0
#
#    First Aid Station   Latitude  Longitude
# 0                  4  40.870022  29.128099
# 1                  2  41.179635  28.745557
# 2                  3  40.977382  29.107801
# 3                  0  40.991604  28.717076
# 4                  6  41.042299  28.844779

# %%
mergedDfClustering = merged_df.copy()

# %%
mergedDfClustering['Firs Aid Ratio'] = mergedDfClustering['Ambulance_Ratio']*mergedDfClustering['First Aid Station']

# %%
mergedDfClustering.head()
# Out:
#       Borough  Emergency_Service_Ratio  Ambulance_Ratio  Bed_Counts  \
# 0      ADALAR                 1.000000         1.000000      1105.0
# 1  ARNAVUTKÖY                 1.000000         0.500000       235.0
# 2    ATASEHIR                 1.000000         1.000000       930.0
# 3     AVCILAR                 1.000000         0.500000       366.0
# 4    BAGCILAR                 0.916667         0.458333      1658.0
#
#    First Aid Station   Latitude  Longitude  Firs Aid Ratio
# 0                  4  40.870022  29.128099            4.00
# 1                  2  41.179635  28.745557            1.00
# 2                  3  40.977382  29.107801            3.00
# 3                  0  40.991604  28.717076            0.00
# 4                  6  41.042299  28.844779            2.75

# %%
mergedDfClustering.drop(columns = ['Borough', 'Latitude', 'Longitude', 'Ambulance_Ratio', 'First Aid Station'], inplace = True)

# %%
mergedDfClustering.head()
# Out:
#    Emergency_Service_Ratio  Bed_Counts  Firs Aid Ratio
# 0                 1.000000      1105.0            4.00
# 1                 1.000000       235.0            1.00
# 2                 1.000000       930.0            3.00
# 3                 1.000000       366.0            0.00
# 4                 0.916667      1658.0            2.75

# %% [markdown]
# At last our dataframe is ready for using in clustering.

# %% [markdown]
# ## 5. Modeling <a name="modeling"></a>

# %% [markdown]
# In clustering, we look at the data and then try to club similar observations and form different groups. Hence it is an unsupervised learning problem.
# Clustering is a widely used technique in data driven sectors. It is actually being used in almost every domain, ranging from banking to helth, image recognition to business.

# %% [markdown]
# K-means is a centroid-based algorithm, or a distance-based algorithm, where we calculate the distances to assign a point to a cluster. In K-Means, each cluster is associated with a centroid.

# %% [markdown]
# We will first normalize the dataset.

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(mergedDfClustering)

# statistics of scaled data
pd.DataFrame(data_scaled).head()
# Out:
#           0         1         2
# 0  0.490153  0.336789  1.068740
# 1  0.490153 -0.865224 -0.788590
# 2  0.490153  0.095005  0.449630
# 3  0.490153 -0.684231 -1.407701
# 4 -0.570184  1.100827  0.294853

# %% [markdown]
# Using the K-Means++ algorithm, we optimize the step where we randomly pick the cluster centroid. We are more likely to find a solution that is competitive to the optimal K-Means solution while using the K-Means++ initialization.

# %%
num_clusters = 4

k_means = KMeans(init="k-means++", n_clusters=num_clusters)
k_means.fit(data_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# One of the most common doubts everyone has while working with K-Means is selecting the right number of clusters.
# One thing we can do is plot a graph, also known as an elbow curve, where the x-axis will represent the number of clusters and the y-axis will be an evaluation metric.

# %% [markdown]
# Let’s evaluate how well the formed clusters are. To do that, we will calculate the inertia of the clusters:

# %%
k_means.inertia_
# Out:
# 29.84851898290674

# %% [markdown]
# We got an inertia value of almost 30. Now, let’s see how we can use the elbow curve to determine the optimum number of clusters in Python.
#
# Second we will fit multiple k-means models and in each successive model, we will increase the number of clusters. We will store the inertia value of each model and then plot it to visualize the result:

# %%
# fitting multiple k-means algorithms and storing the values in an empty list
SSE = []
for cluster in range(1,20):
    k_means = KMeans(n_jobs = -1, n_clusters = cluster, init='k-means++')
    k_means.fit(data_scaled)
    SSE.append(k_means.inertia_)

# converting the results into a dataframe and plotting them
frame = pd.DataFrame({'Cluster':range(1,20), 'SSE':SSE})
plt.pyplot.figure(figsize=(12,6))
plt.pyplot.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.pyplot.xlabel('Number of clusters')
plt.pyplot.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %% [markdown]
# We can choose 4 for number of clusters since we can easily se 4 as a breaking point. Let’s set the number of clusters as 4 and fit the model:

# %%
# k means using 4 clusters and k-means++ initialization
k_means = KMeans(n_jobs = -1, n_clusters = 4, init='k-means++')
k_means.fit(data_scaled)
pred = k_means.predict(data_scaled)

# %%
frame = pd.DataFrame(data_scaled)
frame['cluster'] = pred
dfClusters = frame['cluster'].value_counts().to_frame()

# %%
dfClusters
# Out:
#    cluster
# 0       16
# 3       12
# 1        6
# 2        4

# %% [markdown]
# ## 6. Results and Discussion <a name="results"></a>

# %% [markdown]
# So, we have 4 differen cluster produced by K-means. We can assess them as:
# Very High Capacity, no precedence
# High Capacity, no precedence
# Normal Capacity, to be considered
# Low Capacity, have precedence

# %%
colors_list = ['red', 'cyan','orange','lime']
explode_list = [0, 0, 0, 0] 
# autopct create %, start angle represent starting point
dfClusters['cluster'].plot(kind='pie',
                            figsize=(10, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=30,     # start angle 30°
                            shadow=True,
                            labels=dfClusters.index,# add shadow
                            colors=colors_list,  # add custom colors
                            explode=explode_list
                            )

plt.pyplot.title('Percentage of Clusters')
plt.pyplot.axis('equal') # Sets the pie chart to look like a circle.

plt.pyplot.show()

# %% [markdown]
# After now we can label boroughs according to their clusters by means of their health and medical capability.

# %%
mergedDfClustered = merged_df.copy()
mergedDfClustered.insert(1, 'Cluster Labels', k_means.labels_)
mergedDfClustered.head()
# Out:
#       Borough  Cluster Labels  Emergency_Service_Ratio  Ambulance_Ratio  \
# 0      ADALAR               3                 1.000000         1.000000
# 1  ARNAVUTKÖY               0                 1.000000         0.500000
# 2    ATASEHIR               3                 1.000000         1.000000
# 3     AVCILAR               0                 1.000000         0.500000
# 4    BAGCILAR               1                 0.916667         0.458333
#
#    Bed_Counts  First Aid Station   Latitude  Longitude
# 0      1105.0                  4  40.870022  29.128099
# 1       235.0                  2  41.179635  28.745557
# 2       930.0                  3  40.977382  29.107801
# 3       366.0                  0  40.991604  28.717076
# 4      1658.0                  6  41.042299  28.844779

# %%
# Creating map of Istanbul.
address = "Istanbul, ON"

geolocator = Nominatim(user_agent="istanbul_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Istanbul city are {}, {}.'.format(latitude, longitude))

istanbul_map = folium.Map(location=[latitude, longitude], zoom_start=10)
# Out:
# The geograpical coordinate of Istanbul city are 40.9561106, 29.0899629.

# %%
# set color scheme for the clusters
x = np.arange(num_clusters)
ys = [i + x + (i*x)**2 for i in range(num_clusters)]
colors_array = colors_list
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(mergedDfClustered['Latitude'], mergedDfClustered['Longitude'], mergedDfClustered['Borough'], mergedDfClustered['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(istanbul_map)

# %% [markdown]
# At last we can Show classified boroughs according to their heath and medical capacity in forms of different colors according to their cluster.

# %%
istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7. Conclusion <a name="conclusion"></a>

# %% [markdown]
# In this project we tried to find a way to classify boroughs and neighborhoods of Istanbul by analyzing data and using classification algorithms.
# As we know in metropolis such as Istanbul, one of the challenging problems is planning and serving medical and health services. It especially gains much more importance in nowadays as humanity continuing to suffer from COVID-19. And we see most affected part is millions who lives in big cities.
# We used dataset which is provided by Istanbul Municipality Open Data Platform. This data set is providing limited information about medical capabilities. It should be considered health and medical service planning depends on much more amount and complexity of data. This project is just a case study example and may not yield high quality results for real life. For more accurate results, the data set must be expanded.
# We used the K-means algorithm as classification tool. We determined optimum k value by Elbow method. We classified boroughs into four clusters by means of their health and medical capabilities. At last we visualized clusters on Istanbul map by different colors according to their clusters.
