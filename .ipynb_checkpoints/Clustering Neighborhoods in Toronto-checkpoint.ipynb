# %% [markdown]
# # Part-1 Preparing Data Frame

# %%
# İmporting dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
#Scraping the WEB Site
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
source = requests.get(url).text

sourceXML = BeautifulSoup(source, 'lxml')
table=sourceXML.find('table')

#creating dataframe with the columns: PostalCode, Borough, and Neighborhood
column_names = ['Postalcode','Borough','Neighborhood']
df = pd.DataFrame(columns = column_names)

tableRows = table.find_all('tr')

for tr in tableRows:
    row=[]
    for td in tr.find_all('td'):
        row.append(td.text.strip())
    if len(row)==3:
        df.loc[len(df)] = row

#Cleanin Not indexed rows
index = df[df['Borough'] == 'Not assigned'].index
df.drop(index, inplace = True)
        
df.head(5)
# Out:
#   Postalcode           Borough                                  Neighborhood
# 2        M3A        North York                                     Parkwoods
# 3        M4A        North York                              Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5        M6A        North York             Lawrence Manor / Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part-2 Adding Geographic Locations

# %%
df_coor = pd.read_csv("https://cocl.us/Geospatial_data")

df_coor.rename(columns={'Postal Code':'Postalcode'},inplace=True)
merged_df = pd.merge(df, df_coor, on='Postalcode')

merged_df.head()
# Out:
#   Postalcode           Borough                                  Neighborhood  \
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 3        M6A        North York             Lawrence Manor / Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# # Part-3 Clustering Neighborhoods

# %%
# !pip install folium
import folium # plotting library

# %%
from geopy.geocoders import Nominatim

# %%
address = "Toronto, ON"

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto city are {}, {}.'.format(latitude, longitude))

toronto_map = folium.Map(location=[latitude, longitude], zoom_start=13)

#Adding markers on map
for lat, lng, borough, neighborhood in zip(
        merged_df['Latitude'], 
        merged_df['Longitude'], 
        merged_df['Borough'], 
        merged_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='Blue',
        fill=True,
        fill_color='Green',
        fill_opacity=0.7,
        parse_html=False).add_to(toronto_map)  


toronto_map
# Out:
# The geograpical coordinate of Toronto city are 43.6534817, -79.3839347.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_nh = merged_df.groupby('Neighborhood')

# %%
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
nh_grouped = merged_df.groupby('Neighborhood').mean().reset_index()
nh_grouped.head()
# Out:
#                                         Neighborhood   Latitude  Longitude
# 0                                          Agincourt  43.794200 -79.262029
# 1                            Alderwood / Long Branch  43.602414 -79.543484
# 2  Bathurst Manor / Wilson Heights / Downsview North  43.754328 -79.442259
# 3                                    Bayview Village  43.786947 -79.385975
# 4                 Bedford Park / Lawrence Manor East  43.733283 -79.419750

# %%
# set number of clusters
kclusters = 5

toronto_nh_clustering = nh_grouped.drop('Neighborhood', 1)
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_nh_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 4, 4, 4, 1, 3, 1, 3, 1])

# %%
nh_grouped.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
nh_grouped
# Out:
#     Cluster Labels                                       Neighborhood  \
# 0                0                                          Agincourt
# 1                2                            Alderwood / Long Branch
# 2                4  Bathurst Manor / Wilson Heights / Downsview North
# 3                4                                    Bayview Village
# 4                4                 Bedford Park / Lawrence Manor East
# ..             ...                                                ...
# 93               4                           Willowdale / Newtonbrook
# 94               0                                             Woburn
# 95               3                                   Woodbine Heights
# 96               4                          York Mills / Silver Hills
# 97               4                                    York Mills West
#
#      Latitude  Longitude
# 0   43.794200 -79.262029
# 1   43.602414 -79.543484
# 2   43.754328 -79.442259
# ...

# %%
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(nh_grouped['Latitude'], nh_grouped['Longitude'], nh_grouped['Neighborhood'], nh_grouped['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(toronto_map)
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
